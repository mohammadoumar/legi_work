# %%
import os
import json

import pandas as pd
from pathlib import Path

# %%
PARENT_DIR = Path(os.getcwd()).parent
bills_dir = PARENT_DIR / "datasets" / "US_2025-2026_119th_Congress_CSV" / "data"
bills_file = bills_dir / "bills.csv"

# %%
bills_dir
# Out:
# WindowsPath('c:/Users/Omara KHAN/Desktop/legi_work/datasets/US_2025-2026_119th_Congress_CSV/data')

# %%
df = pd.read_csv(bills_file)

# %%
df.head()
# Out:
#    bill_id  session_id bill_number  status status_desc status_date  \
# 0  2032901        2199         HB1       4      Passed  2025-07-04
# 1  2091821        2199         HB2       0         NaN         NaN
# 2  2091737        2199         HB3       0         NaN         NaN
# 3  2036128        2199         HB4       4      Passed  2025-07-24
# 4  2091568        2199         HB5       0         NaN         NaN
#
#                          title  \
# 0  FEHB Protection Act of 2025
# 1    Reserved for the Speaker.
# 2    Reserved for the Speaker.
# 3      Rescissions Act of 2025
# 4    Reserved for the Speaker.
#
#                                          description  committee_id committee  \
# 0  To provide for reconciliation pursuant to titl...             0       NaN
# 1                          Reserved for the Speaker.             0       NaN
# 2                          Reserved for the Speaker.             0       NaN
# ...

# %%
df.columns
# Out:
# Index(['bill_id', 'session_id', 'bill_number', 'status', 'status_desc',
#        'status_date', 'title', 'description', 'committee_id', 'committee',
#        'last_action_date', 'last_action', 'url', 'state_link'],
#       dtype='object')

# %%
df.iloc[0]
# Out:
# bill_id                                                       2032901
# session_id                                                       2199
# bill_number                                                       HB1
# status                                                              4
# status_desc                                                    Passed
# status_date                                                2025-07-04
# title                                     FEHB Protection Act of 2025
# description         To provide for reconciliation pursuant to titl...
# committee_id                                                        0
# committee                                                         NaN
# last_action_date                                           2025-07-04
# last_action                             Became Public Law No: 119-21.
# url                             https://legiscan.com/US/bill/HB1/2025
# ...
